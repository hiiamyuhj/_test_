# %%
import numpy as np
np.linspace(-3,3)
# Out:
# array([-3.        , -2.87755102, -2.75510204, -2.63265306, -2.51020408,
#        -2.3877551 , -2.26530612, -2.14285714, -2.02040816, -1.89795918,
#        -1.7755102 , -1.65306122, -1.53061224, -1.40816327, -1.28571429,
#        -1.16326531, -1.04081633, -0.91836735, -0.79591837, -0.67346939,
#        -0.55102041, -0.42857143, -0.30612245, -0.18367347, -0.06122449,
#         0.06122449,  0.18367347,  0.30612245,  0.42857143,  0.55102041,
#         0.67346939,  0.79591837,  0.91836735,  1.04081633,  1.16326531,
#         1.28571429,  1.40816327,  1.53061224,  1.65306122,  1.7755102 ,
#         1.89795918,  2.02040816,  2.14285714,  2.26530612,  2.3877551 ,
#         2.51020408,  2.63265306,  2.75510204,  2.87755102,  3.        ])

# %%
array = np.linspace(-3,3,num=100)
array * 10

# %%
np.random.randint(50,size=100,high=101)
# Out:
# array([ 88,  50,  69,  77,  68,  80,  74,  71,  96,  84,  71,  98,  56,
#         73,  98,  65,  77,  58,  70,  62,  98,  54,  87,  90,  84,  83,
#         53,  67,  75,  55,  94,  84,  95,  65,  53,  50,  54,  98,  52,
#         81,  75,  97,  61,  82,  98,  60,  84,  81,  55,  55,  84,  56,
#         95,  79,  85,  59,  92,  78,  69,  94,  66, 100,  70,  75,  83,
#         86,  85,  80,  69,  63,  96,  64,  93,  68,  88,  88,  92, 100,
#         96,  62,  83,  87,  53,  67,  62,  97,  89,  90,  79,  81,  82,
#         72,  67,  75,  73,  58,  81,  94,  97,  50])

# %%
content = np.random.randint(50,size=(50,5),high=101)

# %%
import pandas as pd
df1 = pd.DataFrame(data=content,
             index=range(1,51),
             columns=['國文','英文','數學','地理','歷史'])
df1
# Out:
#      國文   英文  數學   地理   歷史
# 1    60   59  51   57   78
# 2    80   65  65   70   98
# 3    79   68  71   92   88
# 4    52   71  60   73   76
# 5    53   97  81   89   54
# 6    93   54  90   51   76
# 7    80   71  76   85   64
# 8    85   99  66   61   79
# 9    52   54  91   67   95
# 10   55   51  65   73   90
# 11   54   70  94   57   83
# 12   63   65  99   54   60
# 13   88   83  97   71   56
# 14   68   87  78   52   94
# 15   98   83  64   94   74
# 16   83   63  52   91   57
# 17   58   57  58   80   95
# 18   58   84  50   88   90
# 19   62   69  83   61   65
# 20   73   66  87   55   97
# 21   65   67  63   52   96
# 22   60   75  82   83   80
# 23   96   56  68   75   76
# 24   53   65  66   64   87
# 25   86   71  70   76   66
# 26   95   52  95   50   82
# 27   88   88  55  100   66
# 28   73   74  87   58   92
# 29   98   50  69   60   82
# 30   71   93  69   68   82
# 31   64   77  67   64   81
# 32   65   92  58   53   59
# 33   65   87  54   69  100
# 34   59   95  64   74   70
# 35   96   75  78   52   89
# 36   69   55  53   87   65
# 37   71   75  87   69   52
# 38   86   50  84   89   86
# 39   56   62  80   65   69
# 40   70   87  88   70   98
# 41   57   93  79   94   53
# 42   66   73  86   94   55
# 43   63   90  57   86   53
# 44   89   55  84   84   58
# 45   76   99  84   98   94
# 46   80   71  96   86   83
# 47  100   68  89   56   71
# 48   74  100  85   66  100
# 49   65   56  58   76   86
# 50   86   82  53   92   84

# %%
df1['國文'] + df1['英文'] + df1['數學'] + df1['地理'] + df1['歷史']
# Out:
# 1     305
# 2     378
# 3     398
# 4     332
# 5     374
# 6     364
# 7     376
# 8     390
# 9     359
# 10    334
# 11    358
# 12    341
# 13    395
# 14    379
# 15    413
# 16    346
# 17    348
# 18    370
# 19    340
# 20    378
# 21    343
# 22    380
# 23    371
# 24    335
# 25    369
# 26    374
# 27    397
# 28    384
# 29    359
# 30    383
# 31    353
# 32    327
# 33    375
# 34    362
# 35    390
# 36    329
# 37    354
# 38    395
# 39    332
# 40    413
# 41    376
# 42    374
# 43    349
# 44    370
# 45    451
# 46    416
# 47    384
# 48    425
# 49    341
# 50    397
# dtype: int64
